# %% [markdown]
# <a href="https://www.kaggle.com/code/surajthakur21/most-watched-anime?scriptVersionId=224434880" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/100-most-watched-anime-in-the-world/most_watched_anime_dataset_100_entries.csv

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("/kaggle/input/100-most-watched-anime-in-the-world/most_watched_anime_dataset_100_entries.csv")

# %%
 df.head()
# Out:
#             Anime Name Most Watched in Country  Ratings  Number of Episodes  \
# 0  Fullmetal Alchemist                  Brazil      8.8               317.0
# 1            Haikyuu!!                  Mexico      9.2               420.0
# 2                  NaN             South Korea      7.4               419.0
# 3               Bleach                  Brazil      6.4                 NaN
# 4     Sword Art Online                     NaN      9.8               327.0
#
#   Animation Studio Name  Budget (in Million USD)  Release Year      Genre  \
# 0              Ufotable                    80.61        1998.0    Fantasy
# 1                 MAPPA                    74.99        2022.0  Adventure
# 2          A-1 Pictures                    59.05        2009.0    Mystery
# 3              Ufotable                    45.35        2002.0    Fantasy
# 4              Madhouse                    15.90        2017.0        NaN
#
#    Duration per Episode (minutes)
# 0                             NaN
# 1                            59.0
# 2                            56.0
# 3                            55.0
# 4                            43.0

# %%
df.isnull().sum()
# Out:
# Anime Name                        10
# Most Watched in Country           10
# Ratings                           10
# Number of Episodes                10
# Animation Studio Name             10
# Budget (in Million USD)           10
# Release Year                      10
# Genre                             10
# Duration per Episode (minutes)    10
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (41, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41 entries, 1 to 99
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Anime Name                      41 non-null     object
#  1   Most Watched in Country         41 non-null     object
#  2   Ratings                         41 non-null     float64
#  3   Number of Episodes              41 non-null     float64
#  4   Animation Studio Name           41 non-null     object
#  5   Budget (in Million USD)         41 non-null     float64
#  6   Release Year                    41 non-null     float64
#  7   Genre                           41 non-null     object
#  8   Duration per Episode (minutes)  41 non-null     float64
# dtypes: float64(5), object(4)
# memory usage: 3.2+ KB

# %%
df.describe()
# Out:
#          Ratings  Number of Episodes  Budget (in Million USD)  Release Year  \
# count  41.000000           41.000000                41.000000     41.000000
# mean    8.158537          252.902439                73.957317   2004.292683
# std     1.174729          149.605950                44.068149      9.935401
# min     6.300000           12.000000                 5.820000   1990.000000
# 25%     7.100000          114.000000                44.880000   1995.000000
# 50%     8.100000          250.000000                61.380000   2002.000000
# 75%     9.400000          381.000000               110.820000   2013.000000
# max     9.900000          491.000000               149.390000   2022.000000
#
#        Duration per Episode (minutes)
# count                       41.000000
# mean                        38.146341
# std                         11.332610
# min                         21.000000
# 25%                         30.000000
# 50%                         37.000000
# 75%                         45.000000
# max                         59.000000

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df['Anime Name'].unique().shape
# Out:
# (20,)

# %%
 pip install -U kaleido
# Out:
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 19.0 MB/s eta 0:00:00
# Installing collected packages: kaleido
# Successfully installed kaleido-0.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
fig = px.scatter(df, x="Anime Name", y="Number of Episodes", 
                 color="Genre", 
                 title="📺 Number of Episodes per Anime (by Genre)",
                 hover_data=["Anime Name", "Ratings", "Budget (in Million USD)"],  
                 template="plotly_dark",
                 size_max=10)  

fig.update_layout(
    xaxis_title="Anime Name",
    yaxis_title="Number of Episodes",
    font=dict(size=13),
    xaxis_tickangle=-45,  
    yaxis=dict(showgrid=True, gridcolor="lightgrey"),
    xaxis=dict(showgrid=True, gridcolor="lightgrey"),
    height=600, width=900  
)

fig.show()
fig.write_image("plotly_chart.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6c159fc9-dc72-4c74-823e-8755f8746c9e" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c159fc9-dc72-4c74-823e-8755f8746c9e")) {                    Plotly.newPlot(                        "6c159fc9-dc72-4c74-823e-8755f8746c9e",                        [{"customdata":[[9.2,74.99],[9.4,127.22],[8.1,83.5],[6.7,89.19],[9.5,49.08],[7.9,104.84]],"hovertemplate":"Genre=Adventure\u003cbr\u003eAnime Name=%{x}\u003cbr\u003eNumber of Episodes=%{y}\u003cbr\u003eRatings=%{customdata[0]}\u003cbr\u003eBudget (in Million USD)=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Adventure","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Adventure","orientation":"v","showlegend":true,"x":["Haikyuu!!","Bleach","Naruto","One Piece","Hunter x Hunter","Black Clover"],"xaxis":"x","y":[420.0,47.0,482.0,64.0,286.0,404.0],"yaxis":"y","type":"scatter"},{"customdata":[[6.9,13.41],[8.5,50.21],[6.3,25.77],[9.4,137.37],[6.8,59.78]],"hovertemplate":"Genre=Comedy\u003cbr\u003eAnime Name=%{x}\u003cbr\u003eNumber of Episodes=%{y}\u003cbr\u003eRatings=%{customdata[0]}\u003cbr\u003eBudget (in Million USD)=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Comedy","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Comedy","orientation":"v","showlegend":true,"x":["Tokyo Ghoul","Attack on Titan","Naruto","One Piece","My Hero Academia"],"xaxis":"x","y":[153.0,376.0,128.0,69.0,250.0],"yaxis":"y","type":"scatter"},{"customdata":[[7.0,32.7],[9.4,110.82],[9.6,145.33],[7.3,137.95],[6.3,9.62]],"hovertemplate":"Genre=Action\u003cbr\u003eAnime Name=%{x}\u003cbr\u003eNumber of Episodes=%{y}\u003cbr\u003eRatings=%{customdata[0]}\u003cbr\u003eBudget (in Million USD)=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Action","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Action","orientation":"v","showlegend":true,"x":["Tokyo Ghoul","Tokyo Ghoul","My Hero Academia","Hunter x Hunter","Naruto"],"xaxis":"x","y":[154.0,62.0,74.0,450.0,12.0],"yaxis":"y","type":"scatter"},{"customdata":[[9.9,117.41],[6.8,146.16],[9.9,61.38],[6.9,60.63],[9.9,12.24]],"hovertemplate":"Genre=Thriller\u003cbr\u003eAnime Name=%{x}\u003cbr\u003eNumber of Episodes=%{y}\u003cbr\u003eRatings=%{customdata[0]}\u003cbr\u003eBudget (in Million USD)=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thriller","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Thriller","orientation":"v","showlegend":true,"x":["Mob Psycho 100","Neon Genesis Evangelion","Demon Slayer","Neon Genesis Evangelion","Death Note"],"xaxis":"x","y":[365.0,226.0,361.0,381.0,485.0],"yaxis":"y","type":"scatter"},{"customdata":[[7.1,149.39],[7.5,34.16],[8.7,16.91]],"hovertemplate":"Genre=Supernatural\u003cbr\u003eAnime Name=%{x}\u003cbr\u003eNumber of Episodes=%{y}\u003cbr\u003eRatings=%{customdata[0]}\u003cbr\u003eBudget (in Million USD)=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Supernatural","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Supernatural","orientation":"v","showlegend":true,"x":["Neon Genesis Evangelion","Demon Slayer","Spirited Away"],"xaxis":"x","y":[458.0,353.0,301.0],"yaxis":"y","type":"scatter"},{"customdata":[[9.4,103.52],[8.3,64.49],[9.8,138.77],[7.5,58.25]],"hovertemplate":"Genre=Psychological\u003cbr\u003eAnime Name=%{x}\u003cbr\u003eNumber of Episodes=%{y}\u003cbr\u003eRatings=%{customdata[0]}\u003cbr\u003eBudget (in Million USD)=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Psychological","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"P ...

# %%
fig = px.bar(df, x="Number of Episodes", y="Anime Name", 
             title="📺 Number of Episodes per Anime",
             text="Number of Episodes", 
             color="Number of Episodes",  
             orientation="h",  
             color_continuous_scale="blues")  

fig.update_traces(texttemplate='%{text}', textposition="outside")

fig.update_layout(
    xaxis_title="Number of Episodes",
    yaxis_title="Anime Name",
    font=dict(size=13),
    template="plotly_dark", 
    yaxis=dict(tickmode="linear"), 
)

fig.show()
fig.write_image("plotly_chart.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b6defc20-c614-4b23-b5c4-ed05c1937ac3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6defc20-c614-4b23-b5c4-ed05c1937ac3")) {                    Plotly.newPlot(                        "b6defc20-c614-4b23-b5c4-ed05c1937ac3",                        [{"alignmentgroup":"True","hovertemplate":"Number of Episodes=%{marker.color}\u003cbr\u003eAnime Name=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[420.0,47.0,153.0,482.0,154.0,365.0,226.0,458.0,62.0,74.0,201.0,161.0,69.0,353.0,316.0,64.0,71.0,114.0,376.0,491.0,361.0,435.0,381.0,117.0,286.0,69.0,450.0,240.0,485.0,128.0,290.0,404.0,407.0,69.0,12.0,250.0,301.0,100.0,248.0,396.0,283.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[420.0,47.0,153.0,482.0,154.0,365.0,226.0,458.0,62.0,74.0,201.0,161.0,69.0,353.0,316.0,64.0,71.0,114.0,376.0,491.0,361.0,435.0,381.0,117.0,286.0,69.0,450.0,240.0,485.0,128.0,290.0,404.0,407.0,69.0,12.0,250.0,301.0,100.0,248.0,396.0,283.0],"textposition":"outside","x":[420.0,47.0,153.0,482.0,154.0,365.0,226.0,458.0,62.0,74.0,201.0,161.0,69.0,353.0,316.0,64.0,71.0,114.0,376.0,491.0,361.0,435.0,381.0,117.0,286.0,69.0,450.0,240.0,485.0,128.0,290.0,404.0,407.0,69.0,12.0,250.0,301.0,100.0,248.0,396.0,283.0],"xaxis":"x","y":["Haikyuu!!","Bleach","Tokyo Ghoul","Naruto","Tokyo Ghoul","Mob Psycho 100","Neon Genesis Evangelion","Neon Genesis Evangelion","Tokyo Ghoul","My Hero Academia","Black Clover","Death Note","Re:Zero","Demon Slayer","Fairy Tail","One Piece","Fairy Tail","Re:Zero","Attack on Titan","Dragon Ball Z","Demon Slayer","Spirited Away","Neon Genesis Evangelion","Fairy Tail","Hunter x Hunter","Neon Genesis Evangelion","Hunter x Hunter","Fullmetal Alchemist","Death Note","Naruto","Sword Art Online","Black Clover","Mob Psycho 100","One Piece","Naruto","My Hero Academia","Spirited Away","Sword Art Online","Attack on Titan","Jujutsu Kaisen","My Hero Academia"],"yaxis":"y","type":"bar","texttemplate":"%{text}"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[ ...

# %%
fig = px.scatter_matrix(df, 
                        dimensions=['Ratings', 'Number of Episodes', 'Budget (in Million USD)', 'Release Year'],
                        color='Ratings',  
                        title="📊 Pairplot of Anime Dataset",
                        template="plotly_dark")

fig.update_layout(
    font=dict(size=12),
    width=900, height=900
)

fig.show()
fig.write_image("plotly_chart.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fa3bea78-83fb-450c-b6a2-8c04295e222f" class="plotly-graph-div" style="height:900px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa3bea78-83fb-450c-b6a2-8c04295e222f")) {                    Plotly.newPlot(                        "fa3bea78-83fb-450c-b6a2-8c04295e222f",                        [{"dimensions":[{"axis":{"matches":true},"label":"Ratings","values":[9.2,9.4,6.9,8.1,7.0,9.9,6.8,7.1,9.4,9.6,9.4,9.1,8.3,7.5,9.8,6.7,7.5,7.2,8.5,7.0,9.9,7.4,6.9,8.3,9.5,9.8,7.3,8.3,9.9,6.3,6.8,7.9,7.5,9.4,6.3,6.8,8.7,9.4,8.8,7.2,7.7]},{"axis":{"matches":true},"label":"Number of Episodes","values":[420.0,47.0,153.0,482.0,154.0,365.0,226.0,458.0,62.0,74.0,201.0,161.0,69.0,353.0,316.0,64.0,71.0,114.0,376.0,491.0,361.0,435.0,381.0,117.0,286.0,69.0,450.0,240.0,485.0,128.0,290.0,404.0,407.0,69.0,12.0,250.0,301.0,100.0,248.0,396.0,283.0]},{"axis":{"matches":true},"label":"Budget (in Million USD)","values":[74.99,127.22,13.41,83.5,32.7,117.41,146.16,149.39,110.82,145.33,103.52,130.16,64.49,34.16,60.1,89.19,53.18,57.32,50.21,65.73,61.38,123.6,60.63,13.35,49.08,138.77,137.95,104.62,12.24,25.77,44.88,104.84,58.25,137.37,9.62,59.78,16.91,35.18,54.69,68.53,5.82]},{"axis":{"matches":true},"label":"Release Year","values":[2022.0,1995.0,2019.0,1990.0,2007.0,2000.0,2014.0,2011.0,2002.0,2010.0,1995.0,2006.0,2020.0,1994.0,1992.0,2002.0,1993.0,2017.0,2015.0,1992.0,1990.0,2006.0,2003.0,2000.0,2013.0,2019.0,2006.0,2018.0,1993.0,1999.0,1999.0,2009.0,2013.0,1995.0,2002.0,2000.0,2012.0,1997.0,1993.0,1992.0,2021.0]}],"hovertemplate":"%{xaxis.title.text}=%{x}\u003cbr\u003e%{yaxis.title.text}=%{y}\u003cbr\u003eRatings=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[9.2,9.4,6.9,8.1,7.0,9.9,6.8,7.1,9.4,9.6,9.4,9.1,8.3,7.5,9.8,6.7,7.5,7.2,8.5,7.0,9.9,7.4,6.9,8.3,9.5,9.8,7.3,8.3,9.9,6.3,6.8,7.9,7.5,9.4,6.3,6.8,8.7,9.4,8.8,7.2,7.7],"coloraxis":"coloraxis","symbol":"circle"},"name":"","showlegend":false,"type":"splom"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444444444 ...

# %%
fig = px.density_contour(df, x="Ratings", y="Budget (in Million USD)", 
                         title="📈 KDE Density Plot: Ratings vs Budget")

fig.update_layout(
    xaxis_title="Ratings",
    yaxis_title="Budget (Million USD)",
    template="plotly_dark"
)

fig.show()
fig.write_image("plotly_chart.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e9547888-cef9-45d9-95e7-45964289fda8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9547888-cef9-45d9-95e7-45964289fda8")) {                    Plotly.newPlot(                        "e9547888-cef9-45d9-95e7-45964289fda8",                        [{"contours":{"coloring":"none"},"hovertemplate":"Ratings=%{x}\u003cbr\u003eBudget (in Million USD)=%{y}\u003cbr\u003ecount=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa"},"name":"","showlegend":false,"x":[9.2,9.4,6.9,8.1,7.0,9.9,6.8,7.1,9.4,9.6,9.4,9.1,8.3,7.5,9.8,6.7,7.5,7.2,8.5,7.0,9.9,7.4,6.9,8.3,9.5,9.8,7.3,8.3,9.9,6.3,6.8,7.9,7.5,9.4,6.3,6.8,8.7,9.4,8.8,7.2,7.7],"xaxis":"x","xbingroup":"x","y":[74.99,127.22,13.41,83.5,32.7,117.41,146.16,149.39,110.82,145.33,103.52,130.16,64.49,34.16,60.1,89.19,53.18,57.32,50.21,65.73,61.38,123.6,60.63,13.35,49.08,138.77,137.95,104.62,12.24,25.77,44.88,104.84,58.25,137.37,9.62,59.78,16.91,35.18,54.69,68.53,5.82],"yaxis":"y","ybingroup":"y","type":"histogram2dcontour"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1. ...

# %%
df1 = df[df['Budget (in Million USD)'] > 130].sort_values(by='Budget (in Million USD)', ascending=False).head(5)

fig = px.bar(df1, x="Anime Name", y="Budget (in Million USD)", 
             title="💰 Most High-Budget Anime",
             text="Budget (in Million USD)",  
             color="Anime Name",  
             color_discrete_sequence=px.colors.qualitative.Set1)  

fig.update_traces(texttemplate='%{text:.1f}M', textposition="outside")

fig.update_layout(
    xaxis_title="Anime Name",
    yaxis_title="Budget (Million USD)",
    font=dict(size=13),
    template="plotly_dark", 
    xaxis_tickangle=-15  
)

fig.show()
fig.write_image("plotly_chart.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="295cdc2f-7c7b-48d9-8c4f-e8215d177c75" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("295cdc2f-7c7b-48d9-8c4f-e8215d177c75")) {                    Plotly.newPlot(                        "295cdc2f-7c7b-48d9-8c4f-e8215d177c75",                        [{"alignmentgroup":"True","hovertemplate":"Anime Name=%{x}\u003cbr\u003eBudget (in Million USD)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Neon Genesis Evangelion","marker":{"color":"rgb(228,26,28)","pattern":{"shape":""}},"name":"Neon Genesis Evangelion","offsetgroup":"Neon Genesis Evangelion","orientation":"v","showlegend":true,"text":[149.39,146.16,138.77],"textposition":"outside","x":["Neon Genesis Evangelion","Neon Genesis Evangelion","Neon Genesis Evangelion"],"xaxis":"x","y":[149.39,146.16,138.77],"yaxis":"y","type":"bar","texttemplate":"%{text:.1f}M"},{"alignmentgroup":"True","hovertemplate":"Anime Name=%{x}\u003cbr\u003eBudget (in Million USD)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"My Hero Academia","marker":{"color":"rgb(55,126,184)","pattern":{"shape":""}},"name":"My Hero Academia","offsetgroup":"My Hero Academia","orientation":"v","showlegend":true,"text":[145.33],"textposition":"outside","x":["My Hero Academia"],"xaxis":"x","y":[145.33],"yaxis":"y","type":"bar","texttemplate":"%{text:.1f}M"},{"alignmentgroup":"True","hovertemplate":"Anime Name=%{x}\u003cbr\u003eBudget (in Million USD)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hunter x Hunter","marker":{"color":"rgb(77,175,74)","pattern":{"shape":""}},"name":"Hunter x Hunter","offsetgroup":"Hunter x Hunter","orientation":"v","showlegend":true,"text":[137.95],"textposition":"outside","x":["Hunter x Hunter"],"xaxis":"x","y":[137.95],"yaxis":"y","type":"bar","texttemplate":"%{text:.1f}M"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888 ...

# %%
fig = px.histogram(df, x="Ratings", nbins=15, marginal="box", 
                   color_discrete_sequence=["royalblue"], opacity=0.8)

fig.update_layout(
    title="📊 Distribution of Anime Ratings",
    xaxis_title="Ratings",
    yaxis_title="Count",
    template="plotly_dark",  
    font=dict(size=13),
    bargap=0.1,  
)

fig.show()
fig.write_image("plotly_chart.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="750e48a0-1413-40e1-95aa-4c9dc8f0c137" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("750e48a0-1413-40e1-95aa-4c9dc8f0c137")) {                    Plotly.newPlot(                        "750e48a0-1413-40e1-95aa-4c9dc8f0c137",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Ratings=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"royalblue","opacity":0.8,"pattern":{"shape":""}},"name":"","nbinsx":15,"offsetgroup":"","orientation":"v","showlegend":false,"x":[9.2,9.4,6.9,8.1,7.0,9.9,6.8,7.1,9.4,9.6,9.4,9.1,8.3,7.5,9.8,6.7,7.5,7.2,8.5,7.0,9.9,7.4,6.9,8.3,9.5,9.8,7.3,8.3,9.9,6.3,6.8,7.9,7.5,9.4,6.3,6.8,8.7,9.4,8.8,7.2,7.7],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","hovertemplate":"Ratings=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"royalblue"},"name":"","notched":true,"offsetgroup":"","showlegend":false,"x":[9.2,9.4,6.9,8.1,7.0,9.9,6.8,7.1,9.4,9.6,9.4,9.1,8.3,7.5,9.8,6.7,7.5,7.2,8.5,7.0,9.9,7.4,6.9,8.3,9.5,9.8,7.3,8.3,9.9,6.3,6.8,7.9,7.5,9.4,6.3,6.8,8.7,9.4,8.8,7.2,7.7],"xaxis":"x2","yaxis":"y2","type":"box"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333," ...

# %%
fig = px.box(df, x="Genre", y="Budget (in Million USD)", 
             color="Genre",  
             template="plotly_dark", 
             boxmode="group")

fig.update_layout(
    title="💰 Anime Budget Distribution by Genre",
    xaxis_title="Genre",
    yaxis_title="Budget (Million USD)",
    font=dict(size=13),
    xaxis_tickangle=-45,  
    showlegend=False  
)

fig.show()
fig.write_image("plotly_chart.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f8259cea-351c-4118-8aec-f5a67dce2248" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8259cea-351c-4118-8aec-f5a67dce2248")) {                    Plotly.newPlot(                        "f8259cea-351c-4118-8aec-f5a67dce2248",                        [{"alignmentgroup":"True","hovertemplate":"Genre=%{x}\u003cbr\u003eBudget (in Million USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Adventure","marker":{"color":"#636efa"},"name":"Adventure","notched":false,"offsetgroup":"Adventure","orientation":"v","showlegend":true,"x":["Adventure","Adventure","Adventure","Adventure","Adventure","Adventure"],"x0":" ","xaxis":"x","y":[74.99,127.22,83.5,89.19,49.08,104.84],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Genre=%{x}\u003cbr\u003eBudget (in Million USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Comedy","marker":{"color":"#EF553B"},"name":"Comedy","notched":false,"offsetgroup":"Comedy","orientation":"v","showlegend":true,"x":["Comedy","Comedy","Comedy","Comedy","Comedy"],"x0":" ","xaxis":"x","y":[13.41,50.21,25.77,137.37,59.78],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Genre=%{x}\u003cbr\u003eBudget (in Million USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Action","marker":{"color":"#00cc96"},"name":"Action","notched":false,"offsetgroup":"Action","orientation":"v","showlegend":true,"x":["Action","Action","Action","Action","Action"],"x0":" ","xaxis":"x","y":[32.7,110.82,145.33,137.95,9.62],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Genre=%{x}\u003cbr\u003eBudget (in Million USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thriller","marker":{"color":"#ab63fa"},"name":"Thriller","notched":false,"offsetgroup":"Thriller","orientation":"v","showlegend":true,"x":["Thriller","Thriller","Thriller","Thriller","Thriller"],"x0":" ","xaxis":"x","y":[117.41,146.16,61.38,60.63,12.24],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Genre=%{x}\u003cbr\u003eBudget (in Million USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Supernatural","marker":{"color":"#FFA15A"},"name":"Supernatural","notched":false,"offsetgroup":"Supernatural","orientation":"v","showlegend":true,"x":["Supernatural","Supernatural","Supernatural"],"x0":" ","xaxis":"x","y":[149.39,34.16,16.91],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Genre=%{x}\u003cbr\u003eBudget (in Million USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Psychological","marker":{"color":"#19d3f3"},"name":"Psychological","notched":false,"offsetgroup":"Psychological","orientation":"v","showlegend":true,"x":["Psychological","Psychological","Psychological","Psychological"],"x0":" ","xaxis":"x","y":[103.52,64.49,138.77,58.25],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Genre=%{x}\u003cbr\u003eBudget (in Million USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fantasy","marker":{"color":"#FF6692"},"name":"Fantasy","notched":false,"offsetgroup":"Fantasy","orientation":"v","showlegend":true,"x":["Fantasy","Fantasy","Fantasy"],"x0":" ","xaxis":"x","y":[130.16,57.32,5.82],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Genre=%{x}\u003cbr\u003eBudget (in Million USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mystery","marker":{"color":"#B6E880"},"name":"Mystery","notched":false,"offsetgroup":"Mystery","orientation":"v","showlegend":true,"x":["Mystery","Mystery","Mystery","Mystery","Mystery","Mystery"],"x0":" ","xaxis":"x","y":[60.1,53.18,65.73,123.6,13. ...

# %%
fig = px.scatter(df, x="Budget (in Million USD)", y="Ratings", 
                 color="Genre",  
                 hover_data=["Anime Name", "Animation Studio Name"],  
                 template="plotly_dark",  
                 opacity=0.8)  

fig.update_layout(
    title="💰 Budget vs Ratings of Anime",
    xaxis_title="Budget (Million USD)",
    yaxis_title="Ratings",
    font=dict(size=13),
    legend_title="Genre"
)

fig.show()
fig.write_image("plotly_chart.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7533d81f-5bad-439f-a8e2-97dd8a445b50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7533d81f-5bad-439f-a8e2-97dd8a445b50")) {                    Plotly.newPlot(                        "7533d81f-5bad-439f-a8e2-97dd8a445b50",                        [{"customdata":[["Haikyuu!!","MAPPA"],["Bleach","MAPPA"],["Naruto","MAPPA"],["One Piece","Studio Ghibli"],["Hunter x Hunter","MAPPA"],["Black Clover","Wit Studio"]],"hovertemplate":"Genre=Adventure\u003cbr\u003eBudget (in Million USD)=%{x}\u003cbr\u003eRatings=%{y}\u003cbr\u003eAnime Name=%{customdata[0]}\u003cbr\u003eAnimation Studio Name=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Adventure","marker":{"color":"#636efa","opacity":0.8,"symbol":"circle"},"mode":"markers","name":"Adventure","orientation":"v","showlegend":true,"x":[74.99,127.22,83.5,89.19,49.08,104.84],"xaxis":"x","y":[9.2,9.4,8.1,6.7,9.5,7.9],"yaxis":"y","type":"scatter"},{"customdata":[["Tokyo Ghoul","MAPPA"],["Attack on Titan","Wit Studio"],["Naruto","Bones"],["One Piece","Madhouse"],["My Hero Academia","Studio Ghibli"]],"hovertemplate":"Genre=Comedy\u003cbr\u003eBudget (in Million USD)=%{x}\u003cbr\u003eRatings=%{y}\u003cbr\u003eAnime Name=%{customdata[0]}\u003cbr\u003eAnimation Studio Name=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Comedy","marker":{"color":"#EF553B","opacity":0.8,"symbol":"circle"},"mode":"markers","name":"Comedy","orientation":"v","showlegend":true,"x":[13.41,50.21,25.77,137.37,59.78],"xaxis":"x","y":[6.9,8.5,6.3,9.4,6.8],"yaxis":"y","type":"scatter"},{"customdata":[["Tokyo Ghoul","Ufotable"],["Tokyo Ghoul","MAPPA"],["My Hero Academia","Bones"],["Hunter x Hunter","Bones"],["Naruto","Toei Animation"]],"hovertemplate":"Genre=Action\u003cbr\u003eBudget (in Million USD)=%{x}\u003cbr\u003eRatings=%{y}\u003cbr\u003eAnime Name=%{customdata[0]}\u003cbr\u003eAnimation Studio Name=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Action","marker":{"color":"#00cc96","opacity":0.8,"symbol":"circle"},"mode":"markers","name":"Action","orientation":"v","showlegend":true,"x":[32.7,110.82,145.33,137.95,9.62],"xaxis":"x","y":[7.0,9.4,9.6,7.3,6.3],"yaxis":"y","type":"scatter"},{"customdata":[["Mob Psycho 100","Studio Ghibli"],["Neon Genesis Evangelion","Trigger"],["Demon Slayer","Madhouse"],["Neon Genesis Evangelion","Trigger"],["Death Note","Pierrot"]],"hovertemplate":"Genre=Thriller\u003cbr\u003eBudget (in Million USD)=%{x}\u003cbr\u003eRatings=%{y}\u003cbr\u003eAnime Name=%{customdata[0]}\u003cbr\u003eAnimation Studio Name=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thriller","marker":{"color":"#ab63fa","opacity":0.8,"symbol":"circle"},"mode":"markers","name":"Thriller","orientation":"v","showlegend":true,"x":[117.41,146.16,61.38,60.63,12.24],"xaxis":"x","y":[9.9,6.8,9.9,6.9,9.9],"yaxis":"y","type":"scatter"},{"customdata":[["Neon Genesis Evangelion","Trigger"],["Demon Slayer","Wit Studio"],["Spirited Away","Ufotable"]],"hovertemplate":"Genre=Supernatural\u003cbr\u003eBudget (in Million USD)=%{x}\u003cbr\u003eRatings=%{y}\u003cbr\u003eAnime Name=%{customdata[0]}\u003cbr\u003eAnimation Studio Name=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Supernatural","marker":{"color":"#FFA15A","opacity":0.8,"symbol":"circle"},"mode":"markers","name":"Supernatural","orientation":"v","showlegend":true,"x":[149.39,34.16,16.91],"xaxis":"x","y":[7.1,7.5,8.7],"yaxis":"y","type":"scatter"},{"customdata":[["Black Clover","Trigger"],["Re:Zero","Studio Ghibli"],["Neon Genesis Evangelion","Wit Studio"],["Mob Psycho 100","Madhouse"]],"hovertemplate":"Genre=Psychological\u003cbr\u003eBudget  ...

# %%
top_studios = df['Animation Studio Name'].value_counts().head(10).reset_index()
top_studios.columns = ['Studio', 'Count']

fig = px.bar(top_studios, x='Studio', y='Count', 
             text='Count', color='Count',
             color_continuous_scale='Blues',
             title="🎬 Top 10 Animation Studios by Number of Animes")

fig.update_traces(textposition='outside')
fig.update_layout(
    template="plotly_dark",
    font=dict(size=12, color="white"),
    title_font_size=20)

fig.show()
fig.write_image("plotly_chart.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="448ce389-5e1a-4884-98a4-07b691e0428c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("448ce389-5e1a-4884-98a4-07b691e0428c")) {                    Plotly.newPlot(                        "448ce389-5e1a-4884-98a4-07b691e0428c",                        [{"alignmentgroup":"True","hovertemplate":"Studio=%{x}\u003cbr\u003eCount=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[9,7,5,5,4,3,3,3,2],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[9.0,7.0,5.0,5.0,4.0,3.0,3.0,3.0,2.0],"textposition":"outside","x":["MAPPA","Studio Ghibli","Trigger","Madhouse","Wit Studio","Ufotable","Bones","Pierrot","Toei Animation"],"xaxis":"x","y":[9,7,5,5,4,3,3,3,2],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoo ...

# %%
import plotly.figure_factory as ff

corr_matrix = df.corr(numeric_only=True).round(2)
heatmap = ff.create_annotated_heatmap(
    z=corr_matrix.values, 
    x=list(corr_matrix.columns), 
    y=list(corr_matrix.index), 
    colorscale='Cividis',  
    showscale=True)

heatmap.update_layout(
    title="🔥 Correlation Matrix of Anime Dataset",
    font=dict(size=12, color="white"),
    template="plotly_dark",
    title_font_size=20)

heatmap.show()
fig.write_image("plotly_chart.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8bc945c0-24a9-4c91-9ae7-a5af13e1389c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8bc945c0-24a9-4c91-9ae7-a5af13e1389c")) {                    Plotly.newPlot(                        "8bc945c0-24a9-4c91-9ae7-a5af13e1389c",                        [{"colorscale":[[0.0,"#00224e"],[0.1111111111111111,"#123570"],[0.2222222222222222,"#3b496c"],[0.3333333333333333,"#575d6d"],[0.4444444444444444,"#707173"],[0.5555555555555556,"#8a8678"],[0.6666666666666666,"#a59c74"],[0.7777777777777778,"#c3b369"],[0.8888888888888888,"#e1cc55"],[1.0,"#fee838"]],"reversescale":false,"showscale":true,"x":["Ratings","Number of Episodes","Budget (in Million USD)","Release Year","Duration per Episode (minutes)"],"y":["Ratings","Number of Episodes","Budget (in Million USD)","Release Year","Duration per Episode (minutes)"],"z":[[1.0,-0.06,0.24,-0.1,0.03],[-0.06,1.0,-0.0,-0.1,-0.03],[0.24,-0.0,1.0,0.08,-0.02],[-0.1,-0.1,0.08,1.0,0.25],[0.03,-0.03,-0.02,0.25,1.0]],"type":"heatmap"}],                        {"annotations":[{"font":{"color":"#000000"},"showarrow":false,"text":"1.0","x":"Ratings","xref":"x","y":"Ratings","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.06","x":"Number of Episodes","xref":"x","y":"Ratings","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.24","x":"Budget (in Million USD)","xref":"x","y":"Ratings","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.1","x":"Release Year","xref":"x","y":"Ratings","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.03","x":"Duration per Episode (minutes)","xref":"x","y":"Ratings","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.06","x":"Ratings","xref":"x","y":"Number of Episodes","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"1.0","x":"Number of Episodes","xref":"x","y":"Number of Episodes","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.0","x":"Budget (in Million USD)","xref":"x","y":"Number of Episodes","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.1","x":"Release Year","xref":"x","y":"Number of Episodes","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.03","x":"Duration per Episode (minutes)","xref":"x","y":"Number of Episodes","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.24","x":"Ratings","xref":"x","y":"Budget (in Million USD)","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.0","x":"Number of Episodes","xref":"x","y":"Budget (in Million USD)","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"1.0","x":"Budget (in Million USD)","xref":"x","y":"Budget (in Million USD)","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.08","x":"Release Year","xref":"x","y":"Budget (in Million USD)","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.02","x":"Duration per Episode (minutes)","xref":"x","y":"Budget (in Million USD)","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.1","x":"Ratings","xref":"x","y":"Release Year","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"-0.1","x":"Number of Episodes","xref":"x","y":"Release Year","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.08","x":"Budget (in Million USD)","xref":"x","y":"Release Year","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"1.0","x":"Release Year","xref":"x","y":"Release Year","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.25","x":"Duration per Episode (minutes)","xref":"x","y":"Release Year","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0.03","x":"Ratings","xref ...

# %%
fig = px.pie(df, names="Genre", 
             title="🎭 Genre Distribution of Anime",
             color_discrete_sequence=px.colors.qualitative.Set2, 
             hole=0.3)  

fig.update_traces(textinfo="percent+label", 
                  pull=[0.05 if i == df['Genre'].value_counts().idxmax() else 0 for i in df['Genre'].unique()],  # Pops out the most common genre
                  marker=dict(line=dict(color='black', width=1)))  

fig.update_layout(
    showlegend=True,
    font=dict(size=13),
    template="plotly_dark"  
)

fig.show()
fig.write_image("plotly_chart.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="edfe6571-508a-4a5a-9b18-987558993d0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edfe6571-508a-4a5a-9b18-987558993d0d")) {                    Plotly.newPlot(                        "edfe6571-508a-4a5a-9b18-987558993d0d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"Genre=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Adventure","Adventure","Comedy","Adventure","Action","Thriller","Thriller","Supernatural","Action","Action","Psychological","Fantasy","Psychological","Supernatural","Mystery","Adventure","Mystery","Fantasy","Comedy","Mystery","Thriller","Mystery","Thriller","Mystery","Adventure","Psychological","Action","Mystery","Thriller","Comedy","Drama","Adventure","Psychological","Comedy","Action","Comedy","Supernatural","Drama","Sci-Fi","Sci-Fi","Fantasy"],"legendgroup":"","name":"","showlegend":true,"type":"pie","marker":{"line":{"color":"black","width":1}},"pull":[0.05,0,0,0,0,0,0,0,0,0],"textinfo":"percent+label"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f9 ...

# %%
fig = px.treemap(df, path=['Genre'], values='Ratings', 
                 color='Ratings', color_continuous_scale='viridis',
                 title="🌟 Popularity of Anime Genres")

fig.update_layout(margin=dict(t=50, l=25, r=25, b=25),template="plotly_dark")
fig.show()
fig.write_image("plotly_chart.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7c3774c2-f67f-4b5a-bdfc-1f5dc4f1ad0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c3774c2-f67f-4b5a-bdfc-1f5dc4f1ad0f")) {                    Plotly.newPlot(                        "7c3774c2-f67f-4b5a-bdfc-1f5dc4f1ad0f",                        [{"branchvalues":"total","customdata":[[8.143939393939394],[8.585826771653544],[7.761213720316624],[8.308641975308644],[8.080833333333333],[8.153830227743272],[8.844000000000003],[8.080000000000002],[7.826180257510729],[8.937327188940092]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eRatings_sum=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003eRatings=%{color}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Action","Adventure","Comedy","Drama","Fantasy","Mystery","Psychological","Sci-Fi","Supernatural","Thriller"],"labels":["Action","Adventure","Comedy","Drama","Fantasy","Mystery","Psychological","Sci-Fi","Supernatural","Thriller"],"marker":{"coloraxis":"coloraxis","colors":[8.143939393939394,8.585826771653544,7.761213720316624,8.308641975308644,8.080833333333333,8.153830227743272,8.844000000000003,8.080000000000002,7.826180257510729,8.937327188940092]},"name":"","parents":["","","","","","","","","",""],"values":[39.6,50.8,37.9,16.2,24.0,48.300000000000004,35.0,16.0,23.299999999999997,43.400000000000006],"type":"treemap"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dco ...

# %%
fig = px.scatter(df, x="Release Year", y="Ratings", 
                 animation_frame="Release Year", 
                 size="Budget (in Million USD)", 
                 color="Genre",
                 hover_name="Anime Name",
                 title="📈 Anime Ratings Over Time",
                 color_continuous_scale="Plasma")

fig.update_layout(
    template="plotly_dark",  
    font=dict(size=12, color="white"), 
    plot_bgcolor="#222", 
    paper_bgcolor="#222", 
    title_font_size=20)

fig.show()
fig.write_image("plotly_chart.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d9941661-3fb9-428d-86e8-53a721078c50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9941661-3fb9-428d-86e8-53a721078c50")) {                    Plotly.newPlot(                        "d9941661-3fb9-428d-86e8-53a721078c50",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eGenre=Adventure\u003cbr\u003eRelease Year=%{x}\u003cbr\u003eRatings=%{y}\u003cbr\u003eBudget (in Million USD)=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Haikyuu!!"],"legendgroup":"Adventure","marker":{"color":"#636efa","size":[74.99],"sizemode":"area","sizeref":0.37347499999999995,"symbol":"circle"},"mode":"markers","name":"Adventure","orientation":"v","showlegend":true,"x":[2022.0],"xaxis":"x","y":[9.2],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"m ...

# %%
fig = px.choropleth(df, locations="Most Watched in Country", 
                    locationmode='country names', 
                    color="Ratings",
                    hover_name="Most Watched in Country",
                    title="🌍 Most Watched Anime by Country",
                    color_continuous_scale="tealrose")

fig.update_layout(
    geo=dict(showcoastlines=True, showland=True, landcolor="lightgray"),
    template="plotly_dark",
    font=dict(size=12, color="white"),
    title_font_size=20)

fig.show()
fig.write_image("plotly_chart.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="45649758-9108-430a-9a22-3a7c51e17767" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45649758-9108-430a-9a22-3a7c51e17767")) {                    Plotly.newPlot(                        "45649758-9108-430a-9a22-3a7c51e17767",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eMost Watched in Country=%{location}\u003cbr\u003eRatings=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Mexico","China","United Kingdom","China","Australia","Thailand","Argentina","India","United Kingdom","Russia","India","United Kingdom","United States","Australia","Italy","Italy","Canada","Germany","France","Japan","Australia","Argentina","Mexico","United States","Malaysia","United States","France","Japan","Thailand","United States","Germany","Russia","Malaysia","France","United States","Germany","Russia","Germany","Brazil","India","Thailand"],"locationmode":"country names","locations":["Mexico","China","United Kingdom","China","Australia","Thailand","Argentina","India","United Kingdom","Russia","India","United Kingdom","United States","Australia","Italy","Italy","Canada","Germany","France","Japan","Australia","Argentina","Mexico","United States","Malaysia","United States","France","Japan","Thailand","United States","Germany","Russia","Malaysia","France","United States","Germany","Russia","Germany","Brazil","India","Thailand"],"name":"","z":[9.2,9.4,6.9,8.1,7.0,9.9,6.8,7.1,9.4,9.6,9.4,9.1,8.3,7.5,9.8,6.7,7.5,7.2,8.5,7.0,9.9,7.4,6.9,8.3,9.5,9.8,7.3,8.3,9.9,6.3,6.8,7.9,7.5,9.4,6.3,6.8,8.7,9.4,8.8,7.2,7.7],"type":"choropleth"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11 ...
